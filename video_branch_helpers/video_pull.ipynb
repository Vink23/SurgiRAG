# %%
# !pip install yt-dlp
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import subprocess
import os

def download_with_cookies(url, output_dir="./downloads"):
    os.makedirs(output_dir, exist_ok=True)
    
    cmd = [
        "yt-dlp",
        "--cookies-from-browser", "chrome",  # or "firefox"
        "--output", f"{output_dir}/%(title)s.%(ext)s",
        "--format", "best[height<=720]",
        url
    ]
    
    result = subprocess.run(cmd, capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print("Errors:", result.stderr)

# download videos
urls = [
    "https://www.youtube.com/watch?v=FLga2zVyns0",
    "https://www.youtube.com/watch?v=Bw9Esb-APj4", 
    "https://www.youtube.com/watch?v=ia9niBeGJQg",
    "https://www.youtube.com/watch?v=llBobl5rVRY"
]

for url in urls:
    download_with_cookies(url)
# Out:
# Extracting cookies from chrome
# Extracted 3201 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FLga2zVyns0
# [youtube] FLga2zVyns0: Downloading webpage
# [youtube] FLga2zVyns0: Downloading tv client config
# [youtube] FLga2zVyns0: Downloading tv player API JSON
# [info] FLga2zVyns0: Downloading 1 format(s): 18
# [download] Destination: ./downloads/Laparoscopic Cholecystectomy Full HD Video.mp4
#
# [download]   0.0% of   56.38MiB at  Unknown B/s ETA Unknown
# [download]   0.0% of   56.38MiB at    2.81MiB/s ETA 00:20
# [download]   0.0% of   56.38MiB at    4.26MiB/s ETA 00:13
# [download]   0.0% of   56.38MiB at  456.55KiB/s ETA 02:06
# [download]   0.1% of   56.38MiB at  756.32KiB/s ETA 01:16
# [download]   0.1% of   56.38MiB at    1.13MiB/s ETA 00:49
# [download]   0.2% of   56.38MiB at    1.46MiB/s ETA 00:38
# [download]   0.4% of   56.38MiB at    2.05MiB/s ETA 00:27
# [download]   0.9% of   56.38MiB at    3.14MiB/s ETA 00:17
# ...
